# %%
import speech_recognition as sr
import os
import wave
import scipy.io.wavfile as wav
import librosa
import numpy as np
import json
from vosk import Model, KaldiRecognizer, SetLogLevel
from openpyxl import Workbook, load_workbook
from openpyxl.styles import PatternFill
import matplotlib.pyplot as plt

# %%
class Word:
    ''' A class representing a word from the JSON format for vosk speech recognition API '''

    def __init__(self, dict):
        '''
        Parameters:
          dict (dict) dictionary from JSON, containing:
            conf (float): degree of confidence, from 0 to 1
            end (float): end time of the pronouncing the word, in seconds
            start (float): start time of the pronouncing the word, in seconds
            word (str): recognized word
        '''

        self.conf = dict["conf"]
        self.end = dict["end"]
        self.start = dict["start"]
        self.word = dict["word"]

    def to_string(self):
        ''' Returns a string describing this instance '''
        return "{:20} from {:.3f} sec to {:.3f} sec, confidence is {:.2f}%".format(
            self.word, self.start, self.end, self.conf*100)


def is_identical_except_extra_s(str1, str2):
    if len(str1) == len(str2) + 1:
        if str1[:-1] == str2 and str1[-1] == 's':
            return True
    elif len(str2) == len(str1) + 1:
        if str2[:-1] == str1 and str2[-1] == 's':
            return True
    return False


def is_one_char_diff(str1, str2):
    if len(str1) != len(str2):
        return False

    diff_count = 0
    for i in range(len(str1)):
        if str1[i] != str2[i]:
            diff_count += 1
            if diff_count > 1:
                return False

    return diff_count == 1

# Note The threshold depends also on the input volume set on the computer
def _get_voice_onset(signal, threshold = 20, fs=24000, min_time=10):
    '''
    signal : numpy.ndarray
             signal in. Should be the envelope of the raw signal for accurate results
    threshold : int
                Amplitude threshold for voice onset.
                (Threshold = 200 with NYUAD MEG mic at 75% input volume seems to work well)
    fs : int
         Sampling frequency
    min_time : int (ms)
             Time in ms after the threshold is crossed used to calculate
              the median amplitude and decide if it was random burst of noise
              or speech onset.
    '''

    n_above_thresh = int(fs/min_time) # convert time above threshold to number of samples.

    indices_onset = np.where(signal >= threshold)[0] # All indices above threshold
    # Next, find the first index that where the MEDIAN stays above threshold for the next 10ms
    # Not using the MEAN because sensitive to a single extreme value
    # Note 24 points per millesconds (for fs=24000)
    # 10ms = 240 points
    for i in indices_onset:
        median_mintime = np.median(np.abs(signal[i:i+n_above_thresh])) # median value in the timewindow of length min_time
        if median_mintime >= threshold:
            idx_onset = i
            onset_time = idx_onset / float(fs) * 1000.0
            return int(onset_time)
    return np.nan # if no point exceeds the threshold.
                          # Return "None" instead of None in order to be able to append it to a list later on


misidentified_words = {"bee":['b','be','B','beat','beach', 'beer', 'theme','insect','book','big','being','abuse','bay','inside'],
                       "plane":['airplane', 'planner', 'plain','aeroplane'],
                       "pear":['pair', 'pay', 'air','pier','paint','pie','impair','payer'],
                       "sandcastle":['sand', 'same', 'stone', 'castle', 'sun','santos','santa','council'],
                       "boot":['boo', 'shoot', 'bu','boot-up','chew','shoe'],
                       "hanger":['hangar', 'closing', 'hair','hanging','anger','hang'],
                       "bathtub":['bath', 'sink','top'],
                       "ship":['boat', 'sailboat', 'sea', 'sheet','syllable'],
                       "train":['trainer', 'chain', 'training'],
                       "bear":['fare','beer','baron','barren'],
                       "harp":['heart', 'violin', 'hop','arm','higher'],
                       "trumpet":['trumpeter', 'trouble', 'horn', 'trump','drum','trunk','trucks'],
                       "vase":['face', 'bs','boss','ace'],
                       "cannon":['canon', 'canada', 'candidates', 'can', 'kind','kid','candy','wheelbarrow'],
                       "crib":['bed', 'cradle', 'curb', 'caribbean', 'court', 'crapper','crew','cred','craver'],
                       "leg":['lake', 'lang', 'foot', 'logan', 'alike', 'line', 'law','knee','black','bag','dog','deck'],
                       "broom":['brim', 'burn', 'broomstick', 'room', 'blue', 'britain', 'barroom', 'brush', 'bird', 'barone','sweeper','broome', 'brew','bream','boon','brown','mop','mob'],
                       "school":['schoolhouse', 'building', 'ghoul'],
                       "whale":['wheel', 'will', 'wales', 'way', 'weed','win','oil'],
                       "desk":['table', 'drawers', 'deaths','dresser','counter','dust','cabinet'],
                       "table":['desk', 'tape','dust'],
                       "comb":['cone', 'comments', 'cold', 'clone', 'combing', 'calm', 'klum', 'cool','coombe','macomb','helm','cup'],
                       "rose":['rows', 'flower', 'flour','rules'],
                       "camel":['camera', 'candle', 'chemo', 'camo', 'qamar', 'common', 'comment', 'campus', 'capitol','campbell','kim'],
                       "pants":['jeans','genes', 'ponce', 'trousers', 'pets','pounds','pans'],
                       "dress":['address','dresses','dresden','trust','dresser','rest'], #for some reason doesn't work
                       "strawberry":['shrubbery', 'strawberries', 'struggle',"stronger",'shopper'],
                       "arrow":['era', 'barrel', 'air', 'aura','iru','dirt'],
                       "dominoes":['dominance', 'domino', 'dominic', 'dice', 'dominant', 'dominators','dominates','remote','remotes','domain'],
                       "horse":['course', 'force', 'forces', 'forest', 'voice', 'hold','hordes','whole','zebra','whores'],
                       "hammer":['humor', 'counter', 'hamra',"hammer's", 'hama', 'summer','helmet',"haven't",'hip','hand','cameras'],
                       "bed":['dead', 'photos','bit','thud'],
                       "nail":['now', 'knee', 'kneeling', 'meal', 'news','name','kneel','screw','pit','pin','navel','kneeler'],
                       "sandal":['slipper', 'shoe','flip-flop', 'slip', 'sand','slide'],
                       "hippo":['hipaa', 'hippel',"hippopotamus", 'hit', 'hip','rhino','ebook','have'],
                       "card":['car','carter','current', 'cod','court'],
                       "coat":['trenchcoat','code','jacket', 'outfit', 'dress', 'court', 'robe', 'co','coaches','jacketed','towel','chocolate','clothing'],
                       "hair":['wig','here', 'hat', 'hara','girl','week','way','heron','herons'],
                       "bottle":['bottom', 'glass','box','bundle'],
                       "seal":['ceo', 'ceiling','otter','sea','c','psu','thiel','shoe'],
                       "rake":['reek', 'rig', 'b', 'break', 'rick', 'right', 'raid', 'broom','regean','rigor','raker','breaker'],
                       "knife":['knee', 'night','life','next'],
                       "giraffe":['draft', 'draw'],
                       "mittens":['mountains', 'mins', "men's", 'man', 'muppet', 'gloves', 'mentions', 'minions','midland','maintenance','medicine','misses'],
                       "watch":['watcher', 'watching', 'wash', 'water', 'botch', 'washington','clock','wallet'],
                       "dress":['address'],
                       "bathtub":['tub'],
                       "necklace":['net', 'neck', 'bracelet', 'nicholas', 'heart', 'ductless','nicolas'],
                       "tie":['time', 'tai', 'tire', 'top','high','type','ty','suit'],
                       "zebra":['sea', 'zipper', 'disease','sipa','cetera','zip','zero','seabra'],
                       "fish":['field','fisher','fishes','foot','face'],
                       "briefcase":['brief', 'suitcase', 'base', 'purse','bag'],
                       "pool":['swimming'],
                       "elephant":['yellowfin', 'other', 'elegant', 'lesson','alpha','element','elsa'],
                       "beach":['beaches'],
                       "doctor":['dock', 'physician','da','man','mind','mine','teacher','scientist','scientists','police','dude','doctorate'],
                       "saw":['slaw', 'sa', 'size', 'store', 'stock', 'sore','sauce','song','soul','sword','chainsaw','assault','salt'],
                       "bus":['buses', 'van', 'best', 'buffs','boss','bassoon','bustle'],
                       "newspaper":['paper','papers', 'new', 'knees'],
                       "mug":['cup', 'mugen','cook','monk'],
                       "cup":['mug'],
                       "bird":['bored', 'food', 'third', 'burden', 'beard','berta','bud','hummingbird'],
                       "honey":['honeycomb', 'honeymoon', "honey's", 'hoodie','funny','hunting','funding'],
                       "fire":['forest', 'campfires', 'fireplace','flyers', 'furs'],
                       "skirt":['dress','skate', 'schedule','skirting','scott','ska','dresser','skin','scourge','bluffs','screen','script'],
                       "crown":['cron', 'cronin', 'chrome', 'ground', 'count', 'current','tiara','crone','crap','crime'],
                       "spoon":['spooner', 'spin', 'screen','spooning','food','student'],
                       "girl":['grow','crew'],
                       "nurse":['maid', 'news', 'nasa', 'waitress', 'nursery', 'girl','somebody','nerds'],
                       "stapler":['staple', 'stupid','stupor','steeper'],
                       "hospital":['osp', 'close', 'hostel', 'house','hole','husband','hostile'],
                       "glass":['cup','goss'],
                       "dog":['puppy', 'dogara', 'door','dark'],
                       "purse":['bag', 'person', 'puss','satchel','briefcase'],
                       "tunnel":['mine', 'railway', 'railroad', 'chain', 'train', 'cave'],
                       "church":['school', 'chapel', 'churches','charge','trick'],
                       "shovel":['shop', 'chabot', 'shepard', 'shuttle', 'spade', 'shoveling','shivers','shows','shelter','shove'],
                       "lobster":['crab', 'crop', 'lab','luxury','love'],
                       "stethoscope":['set', 'step','stuff','desert','telescope'],
                       "star":['start', 'stall','store'],
                       "door":['doran'],
                       "pill":['pelicans', 'pool', 'pools', 'pins','medicine', 'pillows','vitamins'],
                       "yarn":['yuan', 'jan', 'ball','cotton','wool'],
                       "road":['broadened', 'path', 'highway','world'],
                       "balloon":['boon', 'blue', 'buildings', 'baloo', 'bullet','bonus','bulletin','upolu','ballooning'],
                       "vest":['bust', 'fast', 'first','festive','shirt','bus','waistcoat','face'],
                       "heart":['hart', 'harder','hot'],
                       "throne":['chairs', 'chin', 'road', 'surround', 'ground', 'throwing', 'wrong','throat','round','crown','phone','thorough','thrown','cheer','certain'],
                       "baby":['babies', 'bb', 'child','bay','base','paper'],
                       "ring":['ringer', 'wedding', 'rooting', 'diamond','bring','rain'],
                       "crab":['crop', 'cat', 'kravis', 'lobster', 'crime','crumb'],
                       "water":['drop', 'raindrop', 'job', 'droplet','trump','draw','word','candle','waterdrop','truck'],
                       "dart":['dar', 'darker', 'dont', 'air','dot','door','needle'],
                       "acorn":['corner', 'equal','acres','nut','equipment','ache'],
                       "tree":['cheat', 'treat'],
                       "lamp":['link', 'lab', 'length', 'land','lapping', 'lip','eleven','laugh','level','light'],
                       "truck":['check', 'trucker', 'car', 'pickup','choking','trip'],
                       "grass":['gas', 'girls','glasses','growth'],
                       "keyboard":['key', 'computer','keeper'],
                       "scarf":['sky', 'scar','score','scoff','scarves','skier'],
                       "headphones":['headset'],
                       "lightning":['thunder', 'enlightening', 'bolt','lining'],
                       "wallet":['microwave','water','wallach','window'],
                       "radio":['alarm', 'thermometer','tape','video'],
                       "sink":['sinker', 'think','seek'],
                       "shirt":['suit', 'jacket', 'coat', 'code','shop','shot','blouse','shoot','sweater','blast','t-shirt'],
                       "key":['kids','case','tea','king','keep'],
                       "fork":['fourth', 'falcon', 'four', 'fucking','forecasts','fluke','port','food','fog','fuck','park','floor','falls'],
                       "suit":['coat', 'code','tuxedo','jacket','zoo','co','costumes','asu'],
                       "stick":['branch', 'twig', 'steak', 'branches','tickets'],
                       "mop":['room', 'broom','mouth','monk'],
                       "boy":['child','kid'],
                       "pillow":['pillar', 'pennant'],
                       "pan":['past', 'saucepan', 'pod', 'pop', 'ten','pain','pin','panels'],
                       "leaf":['least','leave','lie'],
                       "nest":['nesta', 'eggs', 'nurse', 'dust','mist'],
                       "tape":['tip', 'taper','team','team','tube'],
                       "hat":['hart', 'house','how','half','fedora','half'],
                       "cave":['kate','key','tunnel'],
                       "cat":['couch','catch'],
                       "nose":['news'],
                       "angel":['agent', 'age','intro','angeles','ange'],
                       "chair":['cheer'],
                       "lizard":['dessert', 'alligator', 'salamander', 'iguana', 'guana','delivery','gecko','blizzard'],
                       "book":['bible','buck','button'],
                       "ice":['nice','eyes'],
                       "scissors":['surface', 'system','center','listeners','sisters','desert'],
                       "helicopter":['helicop'],
                       "basket":['boss','best','back','bed'],
                       "frog":['front','toad','folk','frogger','fraud','frock','prague','phone','fog'],
                       "sheep":['shape','cheaper'],
                       "gun":['guts','good','revolver'],
                       "clock":["o'clock"],
                       "sun":['so'],
                       "anchor":['acres', 'anca','anger','anger','ink','anchorage'],
                       "computer":['desktop','competes','monitor','tv','keyboard','q'],
                       "car":['call','code'],
                       "house":['home','barn'],
                       "foot":['feet','ankle'],
                       "money":['cash'],
                       "goat":['ram','gas','go','good','sheep','gutter','gulf']}
banned_words = {"the","is","and","in"}
#KEY FOR HIGHLIGHTING
#Yellow: There is >300ms or <25ms gap between Speech Onset & A Onset or Speech onset > A onset
#Red: If ABC onset are not in chronological order

# %%
# specify the directory containing the .wav files
dir_path = r"C:\Users\James Belanger\Documents\Relatedness_and_Frequency\Cache"
model_path = r"C:\Users\James Belanger\.cache\Vosk\vosk-model-en-us-0.22"
directories = [name for name in os.listdir(dir_path) if os.path.isdir(os.path.join(dir_path, name))]
model = Model(model_path)
col_num=[9,10,11,12]
yellow_fill = PatternFill(start_color='FFFF00', end_color='FFFF00', fill_type='solid')
red_fill = PatternFill(start_color='FF0000', end_color='FF0000', fill_type='solid')
for directory in directories:
    
    # get the list of .wav files in the directory, sorted by numerical value
    file_list = sorted([f for f in os.listdir(os.path.join(dir_path, directory)) if f.endswith(".wav")], key=lambda x: int(x.split(".")[0]))
    if not(directory + "_Results.xlsx" in file_list):
        
        # create a recognizer object
        r = sr.Recognizer()

        # load the pre-existing workbook and select the active worksheet
        workbook = load_workbook(filename=os.path.join(dir_path, directory, directory+".xlsx"))
        worksheet = workbook.active

        # starting row for all measurements
        next_row = 3
        # traverse the directory and find all the .wav files
        for file_name in file_list:
            if file_name.endswith(".wav"):
                # specify the path to the .wav file
                wav_file = os.path.join(dir_path, directory, file_name)

                # use librosa to load the .wav file and get the time series and sample rate
                y, sample_rate = librosa.load(wav_file, sr=None)
                
                # Set threshold
                threshold = .001

                # Find indices where absolute value is greater than threshold
                indices = np.where(np.abs(y) > threshold)[0]
                #first_index = indices[0]
                
                # use the recognizer to open and read the .wav file
                fs, signal = wav.read(wav_file)
                onset_ms =_get_voice_onset(signal)
                first_index = int(fs * onset_ms / 1000.0)
                wf = wave.open(wav_file, "rb")
                rec = KaldiRecognizer(model, wf.getframerate())
                rec.SetWords(True)

                # get the list of JSON dictionaries
                results = []
                # recognize speech using vosk model
                while True:
                    data = wf.readframes(4000)
                    if len(data) == 0:
                        break
                    if rec.AcceptWaveform(data):
                        part_result = json.loads(rec.Result())
                        results.append(part_result)
                part_result = json.loads(rec.FinalResult())
                results.append(part_result)

                # convert list of JSON dictionaries to list of 'Word' objects
                list_of_words = []
                for sentence in results:
                    if len(sentence) == 1:
                        # sometimes there are bugs in recognition 
                        # and it returns an empty dictionary
                        # {'text': ''}
                        continue
                    for obj in sentence['result']:
                        w = Word(obj)  # create custom Word object
                        list_of_words.append(w)  # and add it to list

                wf.close()  # close audiofile
                
                #WHITE SPACE
                win = 21000 #samples per 500 ms, all files are 24000Hz(samples/sec) (24000x(x secs), win is set at .9 something sec)
                null_spaces= []
                ii = first_index
                next_column = 13
                while ii < len(y)-win:
                    yi_max=np.amax(y[ii:ii+win])
                    if yi_max < threshold:
                            begin = ii
                            while ii < len(y)-win:
                                yi_max=np.amax(y[ii:ii+win])
                                if yi_max > threshold:
                                    end= ii+win
                                    null_spaces.append([int((begin/sample_rate)*1000),int((end/sample_rate)*1000)])
                                    break
                                ii+=1
                    ii+=1
                if null_spaces:
                    for null_values in null_spaces:
                        for null_value in null_values:
                            worksheet.cell(row=next_row, column=next_column).value = null_value
                            next_column += 1
                            
                            
                # add the onset time in ms to the Excel worksheet
                worksheet.cell(row=next_row, column=9).value = onset_ms 
                response = ""
                for word in list_of_words:
                    if word.word == "in":
                        response = response + "and "
                    else:
                        response = response + word.word + " "
                response = response[:-1]
                worksheet.cell(row=next_row, column=7).value = response

                target = worksheet.cell(row=next_row, column=6).value

                if target == response:
                    worksheet.cell(row=next_row, column=8).value = 1
                    worksheet.cell(row=next_row, column=7).value = "c"
                else:
                    worksheet.cell(row=next_row, column=8).value = None


                onset = []
                columns_for_ABC = [[3,10],[4,11],[5,12]]
                ABC_words = []

                for columns in columns_for_ABC:
                    ABC_words.append(worksheet.cell(row=next_row, column=columns[0]).value)
                    target_words = [ABC_words[-1]]
                    if target_words[0] in misidentified_words.keys():
                        target_words = target_words + misidentified_words[target_words[0]]
                    for alternates in target_words:
                        word = 0
                        while word < len(list_of_words):
                            if alternates == list_of_words[word].word:
                                worksheet.cell(row=next_row, column=columns[1]).value = int(list_of_words[word].start*1000)
                                onset.append(int(list_of_words[word].start*1000))
                                break
                            elif is_identical_except_extra_s(alternates, list_of_words[word].word):
                                worksheet.cell(row=next_row, column=columns[1]).value = int(list_of_words[word].start*1000)
                                onset.append(int(list_of_words[word].start*1000))
                                break
                            elif is_one_char_diff(alternates, list_of_words[word].word) and not (list_of_words[word].word in banned_words):
                                worksheet.cell(row=next_row, column=columns[1]).value = int(list_of_words[word].start*1000)
                                onset.append(int(list_of_words[word].start*1000))
                                break
                            word+=1
                        if word >= len(list_of_words):
                            worksheet.cell(row=next_row, column=columns[1]).value = None
                            onset.append(None)
                        else:
                            break
                if (0 if worksheet.cell(row=next_row, column=10).value is None else worksheet.cell(row=next_row, column=10).value
                   ) - (0 if worksheet.cell(row=next_row, column=9).value is None else worksheet.cell(row=next_row, column=9).value) > 300:
                    worksheet.cell(row=next_row, column=9).fill = yellow_fill
                if (10000 if worksheet.cell(row=next_row, column=10).value is None else worksheet.cell(row=next_row, column=10).value
                   ) - (0 if worksheet.cell(row=next_row, column=9).value is None else worksheet.cell(row=next_row, column=9).value) < 25:
                    worksheet.cell(row=next_row, column=9).fill = yellow_fill
                for col_i, col_1 in enumerate(col_num):
                    for col_2 in col_num[col_i+1:]:
                        if (0 if worksheet.cell(row=next_row, column=col_1).value is None else worksheet.cell(row=next_row, column=col_1).value) > (10000 if worksheet.cell(row=next_row, column=col_2).value is None else worksheet.cell(row=next_row, column=col_2).value):
                            worksheet.cell(row=next_row, column=col_1).fill = red_fill
                            worksheet.cell(row=next_row, column=col_2).fill = red_fill
                next_row += 1
                del(wf, rec) 
            print("file complete", directory, file_name, ":", response, "Speech onset:", onset_ms,"A onset:", onset[0],"B onset:",onset[1],"C onset:",onset[2])
        del(r)
        # save the workbook to a file
        workbook.save(os.path.join(dir_path, directory, directory + "_Results.xlsx"))
print("All done!")
del model

# %%
# specify the directory containing the .wav files
dir_path = r"C:\Users\James Belanger\Documents\Relatedness_and_Frequency\Cache"
model_path = r"C:\Users\James Belanger\.cache\Vosk\vosk-model-en-us-0.22"
directories = [name for name in os.listdir(dir_path) if os.path.isdir(os.path.join(dir_path, name))]
model = Model(model_path)
col_num=[9,10,11,12]
yellow_fill = PatternFill(start_color='FFFF00', end_color='FFFF00', fill_type='solid')
red_fill = PatternFill(start_color='FF0000', end_color='FF0000', fill_type='solid')
for directory in directories:
    
    # get the list of .wav files in the directory, sorted by numerical value
    file_list = sorted([f for f in os.listdir(os.path.join(dir_path, directory)) if f.endswith(".wav")], key=lambda x: int(x.split(".")[0]))
    if not(directory + "_results.xlsx" in file_list):
        
        # create a recognizer object
        r = sr.Recognizer()

        # load the pre-existing workbook and select the active worksheet
        workbook = load_workbook(filename=os.path.join(dir_path, directory, directory+".xlsx"))
        worksheet = workbook.active

        # starting row for all measurements
        next_row = 3
        # traverse the directory and find all the .wav files
        for file_name in file_list:
            if file_name.endswith(".wav"):
                # specify the path to the .wav file
                wav_file = os.path.join(dir_path, directory, file_name)

                # use librosa to load the .wav file and get the time series and sample rate
                y, sample_rate = librosa.load(wav_file, sr=None)
                
                # use the recognizer to open and read the .wav file
                with sr.AudioFile(wav_file) as source:
                    audio = r.record(source)
                 # use Vosk API to transcribe the audio text and find onset times of ABC
                    try:
                        # Set threshold
                        threshold = .002

                        # Find indices where absolute value is greater than threshold
                        indices = np.where(np.abs(y) > threshold)[0]

                        # Get the index of the first element in the indices array
                        first_index = indices[0]

                        # Calculate onset time in seconds
                        onset_time = first_index / sample_rate

                        # convert the onset time from seconds to milliseconds
                        onset_ms = int(onset_time * 1000)
                    except sr.UnknownValueError:
                        print("ERROR", file_name)
                    except sr.RequestError as e:
                        print("ERROR", file_name, "; {0}".format(e))
                wf = wave.open(wav_file, "rb")
                rec = KaldiRecognizer(model, wf.getframerate())
                rec.SetWords(True)
                # get the list of JSON dictionaries
                results = []
                # recognize speech using vosk model
                while True:
                    data = wf.readframes(4000)
                    if len(data) == 0:
                        break
                    if rec.AcceptWaveform(data):
                        part_result = json.loads(rec.Result())
                        results.append(part_result)
                part_result = json.loads(rec.FinalResult())
                results.append(part_result)

                # convert list of JSON dictionaries to list of 'Word' objects
                list_of_words = []
                for sentence in results:
                    if len(sentence) == 1:
                        # sometimes there are bugs in recognition 
                        # and it returns an empty dictionary
                        # {'text': ''}
                        continue
                    for obj in sentence['result']:
                        w = Word(obj)  # create custom Word object
                        list_of_words.append(w)  # and add it to list

                wf.close()  # close audiofile
                
                #WHITE SPACE
                win = 21000 #samples per 500 ms, all files are 24000Hz(samples/sec) (24000x(xsec), win is set at .9 something sec)
                null_spaces= []
                ii = first_index
                next_column = 13
                while ii < len(y)-win:
                    yi_max=np.amax(y[ii:ii+win])
                    if yi_max < threshold:
                            begin = ii
                            while ii < len(y)-win:
                                yi_max=np.amax(y[ii:ii+win])
                                if yi_max > threshold:
                                    end= ii+win
                                    null_spaces.append([int((begin/sample_rate)*1000),int((end/sample_rate)*1000)])
                                    break
                                ii+=1
                    ii+=1
                if null_spaces:
                    for null_values in null_spaces:
                        for null_value in null_values:
                            worksheet.cell(row=next_row, column=next_column).value = null_value
                            next_column += 1
                            
                            
                # add the onset time in ms to the Excel worksheet
                worksheet.cell(row=next_row, column=9).value = onset_ms 
                response = ""
                for word in list_of_words:
                    if word.word == "in":
                        response = response + "and "
                    else:
                        response = response + word.word + " "
                response = response[:-1]
                worksheet.cell(row=next_row, column=7).value = response

                target = worksheet.cell(row=next_row, column=6).value

                if target == response:
                    worksheet.cell(row=next_row, column=8).value = 1
                    worksheet.cell(row=next_row, column=7).value = "c"
                else:
                    worksheet.cell(row=next_row, column=8).value = None


                onset = []
                columns_for_ABC = [[3,10],[4,11],[5,12]]
                ABC_words = []

                for columns in columns_for_ABC:
                    ABC_words.append(worksheet.cell(row=next_row, column=columns[0]).value)
                    target_words = [ABC_words[-1]]
                    if target_words[0] in misidentified_words.keys():
                        target_words = target_words + misidentified_words[target_words[0]]
                    for alternates in target_words:
                        word = 0
                        while word < len(list_of_words):
                            if alternates == list_of_words[word].word:
                                worksheet.cell(row=next_row, column=columns[1]).value = int(list_of_words[word].start*1000)
                                onset.append(int(list_of_words[word].start*1000))
                                break
                            elif is_identical_except_extra_s(alternates, list_of_words[word].word):
                                worksheet.cell(row=next_row, column=columns[1]).value = int(list_of_words[word].start*1000)
                                onset.append(int(list_of_words[word].start*1000))
                                break
                            elif is_one_char_diff(alternates, list_of_words[word].word) and not (list_of_words[word].word in banned_words):
                                worksheet.cell(row=next_row, column=columns[1]).value = int(list_of_words[word].start*1000)
                                onset.append(int(list_of_words[word].start*1000))
                                break
                            word+=1
                        if word >= len(list_of_words):
                            worksheet.cell(row=next_row, column=columns[1]).value = None
                            onset.append(None)
                        else:
                            break
                if (0 if worksheet.cell(row=next_row, column=10).value is None else worksheet.cell(row=next_row, column=10).value
                   ) - (0 if worksheet.cell(row=next_row, column=9).value is None else worksheet.cell(row=next_row, column=9).value) > 300:
                    worksheet.cell(row=next_row, column=9).fill = yellow_fill
                if (10000 if worksheet.cell(row=next_row, column=10).value is None else worksheet.cell(row=next_row, column=10).value
                   ) - (0 if worksheet.cell(row=next_row, column=9).value is None else worksheet.cell(row=next_row, column=9).value) < 25:
                    worksheet.cell(row=next_row, column=9).fill = yellow_fill
                for col_i, col_1 in enumerate(col_num):
                    for col_2 in col_num[col_i+1:]:
                        if (0 if worksheet.cell(row=next_row, column=col_1).value is None else worksheet.cell(row=next_row, column=col_1).value) > (10000 if worksheet.cell(row=next_row, column=col_2).value is None else worksheet.cell(row=next_row, column=col_2).value):
                            worksheet.cell(row=next_row, column=col_1).fill = red_fill
                            worksheet.cell(row=next_row, column=col_2).fill = red_fill
                next_row += 1
                del(wf, rec) 
            print("file complete", directory, file_name, ":", response, "Speech onset:", onset_ms,"A onset:", onset[0],"B onset:",onset[1],"C onset:",onset[2])
        del(r)
        # save the workbook to a file
        workbook.save(os.path.join(dir_path, directory, directory + "_Results.xlsx"))
print("All done!")
del model
# Out:
# file complete OA23_Freq 83.wav : the coat is above the money and the lizard Speech onset: 1385 A onset: 2280 B onset: 3900 C onset: 5460
# file complete OA23_Freq 85.wav : the radio is above the nurse and the remote Speech onset: 743 A onset: 1470 B onset: 3480 C onset: None
# file complete OA23_Freq 86.wav : the house is below the watch and the nail Speech onset: 975 A onset: 1800 B onset: 3660 C onset: 4500
# file complete OA23_Freq 89.wav : the gun is below the desk and Speech onset: 0 A onset: 1620 B onset: 3150 C onset: None
# file complete OA23_Freq 90.wav : the fire is below the tape and the necklace Speech onset: 895 A onset: 1500 B onset: 3480 C onset: 5280
# file complete OA23_Freq 93.wav : the shirt and the dog arab Speech onset: 0 A onset: 1230 B onset: 2340 C onset: None
# file complete OA23_Freq 94.wav : the book and the hair are above Speech onset: 0 A onset: 1230 B onset: 2100 C onset: None
# file complete OA23_Freq 97.wav : what is that the tickets and the fish are above or below the balloon Speech onset: 1081 A onset: 4590 B onset: 5340 C onset: 6990
# file complete OA23_Freq 99.wav : the door and the computer are below the ship Speech onset: 0 A onset: 1380 B onset: 2040 C onset: 3360
# file complete OA23_Freq 100.wav : the bird and the school are below that drop Speech onset: 663 A onset: 1230 B onset: 2580 C onset: None
# file complete OA23_Freq 101.wav : the pool is above the stapler and the goat Speech onset: 881 A onset: 1380 B onset: 2850 C onset: 3840
# file complete OA23_Freq 102.wav : the foot is above the pills and the skirt Speech onset: 0 A onset: 2009 B onset: 3990 C onset: 4920
# file complete OA23_Freq 103.wav : the bear is above the sandal and the trunk Speech onset: 710 A onset: 1290 B onset: 2820 C onset: None
# file complete OA23_Freq 109.wav : the kitchen is below the goat and the hammer Speech onset: 1424 A onset: 2009 B onset: 3360 C onset: 4019
# file complete OA23_Freq 110.wav : the saw is below the leaf and the Speech onset: 0 A onset: 1440 B onset: 2760 C onset: None
# file complete OA23_Freq 111.wav : the stick and the hanger are above the show Speech onset: 0 A onset: 1586 B onset: 2760 C onset: None
# file complete OA23_Freq 114.wav : the dress and the yarn are above the box Speech onset: 559 A onset: 1410 B onset: 2940 C onset: None
# file complete OA23_Freq 117.wav : the bus and the hippo are below the lake Speech onset: 568 A onset: 1140 B onset: 2220 C onset: None
# file complete OA23_Freq 119.wav : the road and the tub are below the scissors Speech onset: 1019 A onset: 1560 B onset: None C onset: 2700
# file complete OA23_Freq 120.wav : the horse and the balloon are below the church Speech onset: 871 A onset: 1470 B onset: 2280 C onset: 3930
# file complete OA23_Freq 121.wav : the vest is above the cat and the strawberry Speech onset: 0 A onset: 1170 B onset: 2580 C onset: 3360
# file complete OA23_Freq 122.wav : the scissors is above the tree and the bay Speech onset: 614 A onset: 1140 B onset: 2700 C onset: None
# file complete OA23_Freq 126.wav : the shovel is below the card and the way Speech onset: 0 A onset: 1140 B onset: 2430 C onset: None
# file complete OA23_Freq 127.wav : the fork is below the hat Speech onset: 925 A onset: 1230 B onset: 2340 C onset: None
# file complete OA23_Freq 130.wav : the mop is below the heart and the acres Speech onset: 732 A onset: 1980 B onset: 3660 C onset: None
# file complete OA23_Freq 132.wav : the skirt and the airplane are above the cape Speech onset: 818 A onset: 1320 B onset: None C onset: 2400
# file complete OA23_Freq 133.wav : the arrow and the train or above the desk Speech onset: 711 A onset: 1230 B onset: 1890 C onset: 2940
# file complete OA23_Freq 134.wav : the lamp and the angel or above Speech onset: 533 A onset: 1020 B onset: 1770 C onset: None
# file complete OA23_Freq 137.wav : the lizard and the truck are below the harp Speech onset: 894 A onset: 1860 B onset: 2880 C onset: 4380
# file complete OA23_Freq 139.wav : the pan and the ring or below the bed Speech onset: 760 A onset: 1680 B onset: 2550 C onset: None
# file complete OA23_Freq 141.wav : the anchor is above the basket and the pair Speech onset: 0 A onset: 1320 B onset: 2520 C onset: None
# file complete OA23_Freq 142.wav : the grass is above the sheep and the land Speech onset: 875 A onset: 1410 B onset: 2970 C onset: None
# file complete OA23_Freq 143.wav : the seal is above the rake and the hospital Speech onset: 1067 A onset: 1380 B onset: 2640 C onset: 3330
# file complete OA23_Freq 146.wav : the throne is below the nail and the Speech onset: 729 A onset: 1500 B onset: 2820 C onset: None
# file complete OA23_Freq 147.wav : the elephant is below the remotes and the tape Speech onset: 0 A onset: 1620 B onset: None C onset: None
# file complete OA23_Freq 151.wav : the sandcastle and the trumpet or above the knife Speech onset: 500 A onset: 1050 B onset: 2009 C onset: 3090
# file complete OA23_Freq 153.wav : the crown and the spoon are above the glass Speech onset: 790 A onset: 1230 B onset: 1920 C onset: 3240
# file complete OA23_Freq 154.wav : the newspaper and the camel are above the Speech onset: 702 A onset: 1170 B onset: 2130 C onset: None
# file complete OA23_Freq 156.wav : the lobster and the boot or below the car Speech onset: 1515 A onset: 2880 B onset: 4290 C onset: None
# file complete OA23_Freq 158.wav : the tunnel and the necklace are below the beach Speech onset: 0 A onset: 2009 B onset: 3330 C onset: None
# file complete OA23_Rel 2.wav : the dog is above the cat and the tie Speech onset: 0 A onset: 1590 B onset: 3300 C onset: 4140
# file complete OA23_Rel 8.wav : the girl is below the boy and the money Speech onset: 1540 A onset: 2100 B onset: 3810 C onset: 4680
# file complete OA23_Rel 10.wav : the doctor is below the hospital and the newspaper Speech onset: 1123 A onset: 3450 B onset: 5220 C onset: 6150
# file complete OA23_Rel 13.wav : the door and the window or above the keyboard Speech onset: 912 A onset: 1470 B onset: 2190 C onset: 3630
# file complete OA23_Rel 16.wav : the shirt and the pants are below the key Speech onset: 835 A onset: 1830 B onset: 2820 C onset: 4200
# file complete OA23_Rel 21.wav : the bed is above the pillow and the truck Speech onset: 1023 A onset: 1560 B onset: 2910 C onset: 3810
# file complete OA23_Rel 30.wav : the baby is below the crib and the sandcastle Speech onset: 690 A onset: 1650 B onset: 3060 C onset: 3900
# file complete OA23_Rel 33.wav : the gun and the cannon are above the tie Speech onset: 719 A onset: 1200 B onset: 2190 C onset: 3840
# file complete OA23_Rel 34.wav : the honey and the bee are above the throne Speech onset: 886 A onset: 1590 B onset: 2640 C onset: 3930
# file complete OA23_Rel 38.wav : the horse and the camel are below the stethoscope Speech onset: 1350 A onset: 1860 B onset: 2790 C onset: 4860
# file complete OA23_Rel 41.wav : the anchor is above the ship and the crib Speech onset: 1108 A onset: 1680 B onset: 3360 C onset: 4740
# file complete OA23_Rel 43.wav : the skirt is above the dress and the frog Speech onset: 735 A onset: 1110 B onset: 2580 C onset: 3510
# file complete OA23_Rel 47.wav : the chair or the throne is below the king and the frame pan oops one word Speech onset: 1019 A onset: 3180 B onset: 5670 C onset: 8280
# file complete OA23_Rel 53.wav : the comb the wig or above the bus Speech onset: 646 A onset: 1080 B onset: None C onset: 3840
# file complete OA23_Rel 59.wav : the nest and the bird are below the hangar Speech onset: 908 A onset: 1440 B onset: 2310 C onset: 3480
# file complete OA23_Rel 65.wav : the giraffe is above the zebra and the cup Speech onset: 864 A onset: 1320 B onset: 2790 C onset: None
# file complete OA23_Rel 66.wav : the hammer is below the nail and the fish Speech onset: 1046 A onset: 1440 B onset: 2640 C onset: 3300
# file complete OA23_Rel 72.wav : the sheep and the goat are above the door Speech onset: 1141 A onset: 1590 B onset: 2820 C onset: 4140
# file complete OA23_Rel 76.wav : the arrow and the dirt or below the Speech onset: 0 A onset: 1680 B onset: 2460 C onset: None
# file complete OA23_Rel 80.wav : the scarf and mittens are below the horse Speech onset: 1528 A onset: 2190 B onset: 3180 C onset: 4740
# file complete OA23_Rel 81.wav : the beach is above the tie and the fork Speech onset: 1464 A onset: 3300 B onset: 4860 C onset: 5370
# file complete OA23_Rel 87.wav : the tea is below the flower and the cat Speech onset: 876 A onset: None B onset: None C onset: None
# file complete OA23_Rel 88.wav : the table is below the doctor and the camel Speech onset: 896 A onset: 1290 B onset: 3240 C onset: 4080
# file complete OA23_Rel 92.wav : the leg and the ring are above the broom Speech onset: 1937 A onset: 2700 B onset: 3630 C onset: 5190
# file complete OA23_Rel 96.wav : the suit and the clock are below the zebra Speech onset: 0 A onset: 2070 B onset: 3600 C onset: 4740
# file complete OA23_Rel 105.wav : the church is above the dart and the headphones Speech onset: 1353 A onset: 1920 B onset: 3360 C onset: 4260
# file complete OA23_Rel 106.wav : the bed is below the frog and the rake Speech onset: 1428 A onset: 1980 B onset: 3270 C onset: 4080
# file complete OA23_Rel 112.wav : the sun and the broom are above the house Speech onset: 1185 A onset: 1650 B onset: 2400 C onset: 3930
# file complete OA23_Rel 115.wav : the hospital and the lightning are above the elephant Speech onset: 532 A onset: 1680 B onset: 4560 C onset: 6690
# file complete OA23_Rel 118.wav : the bridge and the wallet are below this Speech onset: 1313 A onset: 1710 B onset: 2580 C onset: None
# file complete OA23_Rel 123.wav : the cave is above the nose and the gun Speech onset: 901 A onset: 1860 B onset: 3990 C onset: 4770
# file complete OA23_Rel 125.wav : the nest is above the ice and the crown Speech onset: 721 A onset: 1320 B onset: 4320 C onset: 5310
# file complete OA23_Rel 129.wav : the crab is below the pants and the angel Speech onset: 1011 A onset: 1410 B onset: 2730 C onset: 3750
# file complete OA23_Rel 131.wav : the hammer and the chair are above the dog Speech onset: 1061 A onset: 1500 B onset: 2190 C onset: 3630
# file complete OA23_Rel 136.wav : the mittens and the cake are below the briefcase Speech onset: 682 A onset: 1260 B onset: 2310 C onset: 3960
# file complete OA23_Rel 144.wav : the vase is above the skirt and the computer Speech onset: 969 A onset: 1560 B onset: 3330 C onset: 4290
# file complete OA23_Rel 150.wav : the b is below the scarf and the Speech onset: 898 A onset: None B onset: 1410 C onset: 2640
# file complete OA23_Rel 155.wav : the zebra and the helicopter are above the sun Speech onset: 1184 A onset: 2160 B onset: 3360 C onset: 5280
# file complete OA23_Rel 157.wav : the pillow and the sink are below the tree Speech onset: 996 A onset: 1560 B onset: 2580 C onset: 3960
# file complete OA23_Rel 160.wav : the whale and the acorn are below the clock Speech onset: 1186 A onset: 2580 B onset: 3900 C onset: 5400
# file complete OA24_Freq 83.wav : the coat is below the money and the lizard Speech onset: 1780 A onset: 1860 B onset: 3060 C onset: 3750
# file complete OA24_Freq 85.wav : the radio is below the nurse and that dominoes Speech onset: 1450 A onset: 1590 B onset: 3120 C onset: 6270
# file complete OA24_Freq 86.wav : the house is above the watch and the nail Speech onset: 897 A onset: 990 B onset: 1950 C onset: 2610
# file complete OA24_Freq 89.wav : the gun is above the desk and the hoodie Speech onset: 906 A onset: 1020 B onset: 1890 C onset: None
# file complete OA24_Freq 90.wav : the fire is above the tape and the necklace Speech onset: 721 A onset: 990 B onset: 2130 C onset: 2760
# file complete OA24_Freq 93.wav : the shirt and the dog are below the desk Speech onset: 1477 A onset: 1530 B onset: 2040 C onset: None
# file complete OA24_Freq 94.wav : the book and the wig are below the star Speech onset: 2167 A onset: 2130 B onset: None C onset: 2550
# file complete OA24_Freq 97.wav : the tickets and the fish are above the balloon Speech onset: 1116 A onset: 1230 B onset: 1950 C onset: 2910
# file complete OA24_Freq 99.wav : the door and the computer above the ship Speech onset: 1009 A onset: 1110 B onset: 1560 C onset: 2550
# file complete OA24_Freq 100.wav : the bird and the school or below the draw or above the drop Speech onset: 984 A onset: 1050 B onset: 2040 C onset: None
# file complete OA24_Freq 101.wav : the pool is below the stapler and the goat Speech onset: 1180 A onset: 1260 B onset: 2940 C onset: 3750
# file complete OA24_Freq 102.wav : the foot is below the pills and the skirt Speech onset: 1451 A onset: 1530 B onset: 2760 C onset: 3606
# file complete OA24_Freq 103.wav : the bear is under the slipper and the trumpet Speech onset: 1161 A onset: 1230 B onset: None C onset: 3210
# file complete OA24_Freq 109.wav : the kitchen is above the goat and the hammer Speech onset: 1522 A onset: 1590 B onset: 2610 C onset: 3300
# file complete OA24_Freq 110.wav : the saw is above the leaf and the book Speech onset: 1725 A onset: 1800 B onset: 3030 C onset: 3600
# file complete OA24_Freq 111.wav : the stick and the hangar or below the shovel Speech onset: 1570 A onset: 1675 B onset: 2370 C onset: 3450
# file complete OA24_Freq 114.wav : the dress and the yard or below the bottle Speech onset: 958 A onset: 1050 B onset: 1740 C onset: 2970
# file complete OA24_Freq 117.wav : the bus and a hippo or above the leg Speech onset: 1050 A onset: 1140 B onset: 1590 C onset: 2699
# file complete OA24_Freq 119.wav : the road and the tub or above the scissors Speech onset: 1240 A onset: 1736 B onset: None C onset: 2580
# file complete OA24_Freq 120.wav : the horse and the balloon or above the church Speech onset: 1454 A onset: 1590 B onset: 2220 C onset: 3240
# file complete OA24_Freq 121.wav : the best is below the cat and the strawberry Speech onset: 1223 A onset: 1320 B onset: 2340 C onset: 3030
# file complete OA24_Freq 122.wav : the scissors are below the tree and the baby Speech onset: 1212 A onset: 1290 B onset: 2520 C onset: 3240
# file complete OA24_Freq 126.wav : the shovel is above the card and the whale Speech onset: 1348 A onset: 1410 B onset: 3510 C onset: 4290
# file complete OA24_Freq 127.wav : the fork is above the hat and the pills Speech onset: 1215 A onset: 1290 B onset: 2160 C onset: 2760
# file complete OA24_Freq 130.wav : the mop is above the heart and the acorn Speech onset: 1208 A onset: 1350 B onset: 2160 C onset: 2850
# file complete OA24_Freq 132.wav : the skirt and the plane or blow the cave Speech onset: 1168 A onset: 1260 B onset: 1860 C onset: 2850
# file complete OA24_Freq 133.wav : the arrow and the train or below the desk Speech onset: 1878 A onset: 2040 B onset: 2550 C onset: 3600
# file complete OA24_Freq 134.wav : the lamp and the angel are below the hippo Speech onset: 1123 A onset: 1230 B onset: 1890 C onset: 2970
# file complete OA24_Freq 137.wav : the lizard and the truck or above the harp Speech onset: 1434 A onset: 1560 B onset: 2190 C onset: 3150
# file complete OA24_Freq 139.wav : the pan and the ring are above the basket Speech onset: 513 A onset: 1470 B onset: 1980 C onset: 2970
# file complete OA24_Freq 141.wav : the acre is below the basket and the pair Speech onset: 1064 A onset: None B onset: 1230 C onset: 2160
# file complete OA24_Freq 142.wav : the grass is below the sheep and the lamp Speech onset: 783 A onset: 1470 B onset: 2730 C onset: 3690
# file complete OA24_Freq 143.wav : the seal is below the rake and the hospital Speech onset: 1251 A onset: 1350 B onset: 2550 C onset: 3150
# file complete OA24_Freq 146.wav : the throne is above the nail and the car Speech onset: 1528 A onset: 1620 B onset: 2790 C onset: 3420
# file complete OA24_Freq 147.wav : the elephant is above the dominoes and the tape Speech onset: 1023 A onset: 1170 B onset: 2430 C onset: 3390
# file complete OA24_Freq 151.wav : sandcastle or the trumpet or below the knife Speech onset: 1288 A onset: 1230 B onset: 2250 C onset: 3900
# file complete OA24_Freq 153.wav : the crown and the spoon or below the glass Speech onset: 1327 A onset: 1380 B onset: 1920 C onset: 3450
# file complete OA24_Freq 154.wav : the newspaper or the camel or below the purse Speech onset: 1206 A onset: 1290 B onset: 2070 C onset: 3060
# file complete OA24_Freq 156.wav : the lobster and the boot or above the card Speech onset: 1489 A onset: 2100 B onset: 3240 C onset: 4440
# file complete OA24_Freq 158.wav : the tunnel and the necklace are about to be Speech onset: 961 A onset: 2940 B onset: 3810 C onset: None
# file complete OA24_Rel 2.wav : the dog is below the cat and the tie Speech onset: 1918 A onset: 2009 B onset: 3390 C onset: 4800
# file complete OA24_Rel 8.wav : the girl is above the boy and the money Speech onset: 1497 A onset: 1590 B onset: 2640 C onset: 3300
# file complete OA24_Rel 10.wav : the doctor is above the hospital and the newspaper Speech onset: 1019 A onset: 1110 B onset: 2160 C onset: 2970
# file complete OA24_Rel 13.wav : the door and the window are below the keyboard Speech onset: 1289 A onset: 1380 B onset: 2039 C onset: 3000
# file complete OA24_Rel 16.wav : the shirt and pants are about the key Speech onset: 1366 A onset: 1410 B onset: 1920 C onset: 2790
# file complete OA24_Rel 21.wav : the bed is below the pillow and the truck Speech onset: 1323 A onset: 1380 B onset: 2520 C onset: 3120
# file complete OA24_Rel 30.wav : the baby is above the crib and the same castle Speech onset: 1027 A onset: 1080 B onset: 2460 C onset: None
# file complete OA24_Rel 33.wav : the gun and the canon or below the tie Speech onset: 1457 A onset: 1530 B onset: None C onset: 1950
# file complete OA24_Rel 34.wav : the honey and the bee are below the throne Speech onset: 1191 A onset: 1740 B onset: 2160 C onset: 3240
# file complete OA24_Rel 38.wav : the horse and a camel or above a stethoscope Speech onset: 757 A onset: 1260 B onset: 1740 C onset: 2729
# file complete OA24_Rel 41.wav : the anchor is below the ship and the crib Speech onset: 1379 A onset: 1500 B onset: 2820 C onset: 3630
# file complete OA24_Rel 43.wav : the skirt is below the dress and the frock Speech onset: 1823 A onset: 1920 B onset: 3690 C onset: None
# file complete OA24_Rel 47.wav : the throne is about the king and the pan Speech onset: 1084 A onset: 1170 B onset: 2280 C onset: 3060
# file complete OA24_Rel 53.wav : the comb and the wig are below the bus Speech onset: 1465 A onset: 1560 B onset: None C onset: 2190
# file complete OA24_Rel 59.wav : the nest and the bird are above the hangar Speech onset: 1162 A onset: 1260 B onset: 1739 C onset: 2790
# file complete OA24_Rel 65.wav : the giraffe is below the zebra and the mug Speech onset: 902 A onset: 1380 B onset: 2580 C onset: 3270
# file complete OA24_Rel 66.wav : the hammer is above the nail and the fish Speech onset: 1559 A onset: 1620 B onset: 2580 C onset: 3150
# file complete OA24_Rel 72.wav : the sheep and a goat are below the door Speech onset: 1566 A onset: 1620 B onset: 2130 C onset: 3120
# file complete OA24_Rel 76.wav : the arrow and the dark or above the cone Speech onset: 1001 A onset: 1170 B onset: 2160 C onset: None
# file complete OA24_Rel 80.wav : the scarf and mittens are above the horse Speech onset: 795 A onset: 1770 B onset: 2280 C onset: 3120
# file complete OA24_Rel 81.wav : the the beach is below the tie and the fork Speech onset: 2462 A onset: 3480 B onset: 4860 C onset: 5520
# file complete OA24_Rel 87.wav : the key is above the rose and the cat Speech onset: 1060 A onset: 1050 B onset: 2400 C onset: 3030
# file complete OA24_Rel 88.wav : the table is above the doctor and the camel Speech onset: 1399 A onset: 1500 B onset: 3120 C onset: 4110
# file complete OA24_Rel 92.wav : the leg and the ring are below the broom Speech onset: 2470 A onset: 2580 B onset: 3300 C onset: 4800
# file complete OA24_Rel 96.wav : the suit and the clock are above the zebra zebra Speech onset: 1379 A onset: 1470 B onset: 2009 C onset: 2910
# file complete OA24_Rel 105.wav : the church is below the dar and the headphones Speech onset: 1336 A onset: 1440 B onset: None C onset: 2910
# file complete OA24_Rel 106.wav : the bed is above the frog and the rake Speech onset: 1466 A onset: 1530 B onset: 2520 C onset: 3300
# file complete OA24_Rel 112.wav : the sun and the broom or below the house Speech onset: 1282 A onset: 1380 B onset: 1800 C onset: 2880
# file complete OA24_Rel 115.wav : the hospital and the lightning are below the hell of it Speech onset: 957 A onset: 1590 B onset: 3060 C onset: None
# file complete OA24_Rel 118.wav : the bridge and the wallach are above the spoon Speech onset: 718 A onset: 2340 B onset: None C onset: None
# file complete OA24_Rel 123.wav : the cave is below the nose and the gun Speech onset: 1210 A onset: 1290 B onset: 2490 C onset: 3120
# file complete OA24_Rel 125.wav : the nest is below the ice cubes and the crown Speech onset: 1655 A onset: 1740 B onset: 3240 C onset: 4080
# file complete OA24_Rel 129.wav : the crab is above the pants and the angel Speech onset: 1008 A onset: 1080 B onset: 2340 C onset: 3150
# file complete OA24_Rel 131.wav : the hammer and the chair are below the dog Speech onset: 1271 A onset: 1320 B onset: 1770 C onset: 2820
# file complete OA24_Rel 136.wav : the mittens and a cake or above the briefcase Speech onset: 1281 A onset: 1380 B onset: 1980 C onset: 3150
# file complete OA24_Rel 144.wav : the face is below the skirt and the computer Speech onset: 1061 A onset: None B onset: 1170 C onset: 2280
# file complete OA24_Rel 150.wav : the b is above the scar and the kid Speech onset: 1206 A onset: None B onset: 1320 C onset: None
# file complete OA24_Rel 155.wav : the zebra and the helicopter are below the sun Speech onset: 1147 A onset: 1230 B onset: 2008 C onset: 3420
# file complete OA24_Rel 157.wav : the pillow didn't seek or above the tree Speech onset: 1324 A onset: 1410 B onset: None C onset: None
# file complete OA24_Rel 160.wav : the whale and the acorn are above the clock Speech onset: 762 A onset: 2070 B onset: 2550 C onset: 3570
# file complete OA29_Freq 83.wav : the code is below the money the blizzard okay Speech onset: 4270 A onset: None B onset: None C onset: 4140
# file complete OA29_Freq 85.wav : the radio is below the nurse and the dice dominoes Speech onset: 2152 A onset: 2220 B onset: 3600 C onset: 5190
# file complete OA29_Freq 86.wav : the house school can't remember which one it is is the the watch and the nail Speech onset: 2586 A onset: 2520 B onset: 8250 C onset: 9240
# file complete OA29_Freq 89.wav : the gun is above the desk and the honey Speech onset: 1466 A onset: 1530 B onset: 2520 C onset: 3270
# file complete OA29_Freq 90.wav : the camp or is it the tape and the necklace Speech onset: 3132 A onset: None B onset: None C onset: None
# file complete OA29_Freq 93.wav : the shirt and the dog are below the table Speech onset: 1951 A onset: 1980 B onset: 2580 C onset: 4050
# file complete OA29_Freq 94.wav : the book and the hair below the star Speech onset: 1957 A onset: 2040 B onset: 2580 C onset: 3478
# file complete OA29_Freq 97.wav : the that is but the fish are above the balloon oh yeah tickets yeah you need to have some writing on him Speech onset: 8744 A onset: 13800 B onset: 10470 C onset: 11400
# file complete OA29_Freq 99.wav : the door and the computer above the ship Speech onset: 1547 A onset: 1620 B onset: 2791 C onset: 5010
# file complete OA29_Freq 100.wav : the bird and the school or above the dripping water the rain Speech onset: 2100 A onset: 2190 B onset: 4620 C onset: 8400
# file complete OA29_Freq 101.wav : the pools below the stapler and the gas Speech onset: 1690 A onset: 1800 B onset: 3030 C onset: None
# file complete OA29_Freq 102.wav : the food is below the pills and the skirt Speech onset: 1922 A onset: 1890 B onset: 2970 C onset: 3600
# file complete OA29_Freq 103.wav : the bear is below the house you and the horn trumpet Speech onset: 2102 A onset: 2160 B onset: None C onset: None
# file complete OA29_Freq 109.wav : the kitchen is above the goat and the hammer Speech onset: 1552 A onset: 1650 B onset: 3120 C onset: 3900
# file complete OA29_Freq 110.wav : the size above the leaf and the book Speech onset: 1942 A onset: None B onset: None C onset: None
# file complete OA29_Freq 111.wav : the stick and the hangar or below the shovel Speech onset: 1666 A onset: 1560 B onset: 2310 C onset: 3660
# file complete OA29_Freq 114.wav : the address and the ball of yarn is below the bottle hmm Speech onset: 1835 A onset: None B onset: 1922 C onset: 3720
# file complete OA29_Freq 117.wav : the bus and the hipaa are above the leg Speech onset: 2063 A onset: 2160 B onset: None C onset: 2910
# file complete OA29_Freq 119.wav : the road and the bathtub or above the scissors Speech onset: 1696 A onset: 1830 B onset: 3030 C onset: 4769
# file complete OA29_Freq 120.wav : worse than the balloon or above the church Speech onset: 1182 A onset: 1181 B onset: 1860 C onset: 3060
# file complete OA29_Freq 121.wav : the vest is below the cat and the strawberry Speech onset: 1874 A onset: 1980 B onset: 3270 C onset: 4230
# file complete OA29_Freq 122.wav : the scissors are below the tree and the baby Speech onset: 1955 A onset: 2040 B onset: 3180 C onset: 3750
# file complete OA29_Freq 126.wav : the shovel is above the card and the whale Speech onset: 1736 A onset: 1830 B onset: 3150 C onset: 4320
# file complete OA29_Freq 127.wav : the fork is above the hat and the pills Speech onset: 1772 A onset: 1650 B onset: 2730 C onset: 3510
# file complete OA29_Freq 130.wav : the map is above the heart and acorn Speech onset: 1389 A onset: 1530 B onset: 2490 C onset: 3065
# file complete OA29_Freq 132.wav : the skirt and the plane or below the cave Speech onset: 2745 A onset: 2580 B onset: 3390 C onset: 4590
# file complete OA29_Freq 133.wav : the era when the train are below the desk Speech onset: 1840 A onset: None B onset: 1980 C onset: 2670
# file complete OA29_Freq 134.wav : the lamp and the angel are below the hippopotamus Speech onset: 1747 A onset: 1860 B onset: 2550 C onset: None
# file complete OA29_Freq 137.wav : the lizard and the truck or above the heart Speech onset: 2126 A onset: 2220 B onset: 2970 C onset: None
# file complete OA29_Freq 139.wav : the pan and the ring or above the basket Speech onset: 1417 A onset: 1350 B onset: 1950 C onset: 2940
# file complete OA29_Freq 141.wav : the anchor is below the basket and the pair Speech onset: 1740 A onset: 1860 B onset: 3090 C onset: None
# file complete OA29_Freq 142.wav : the grass is below the sheep and the lamp Speech onset: 1574 A onset: 1620 B onset: 3180 C onset: 3870
# file complete OA29_Freq 143.wav : the seal is below the rake and the hospital Speech onset: 2460 A onset: 2460 B onset: 3750 C onset: 4590
# file complete OA29_Freq 146.wav : the throne is it the the nail and the car Speech onset: 1525 A onset: 1590 B onset: 3060 C onset: 3810
# file complete OA29_Freq 147.wav : the elephant is above the dice and the tape Speech onset: 1354 A onset: 1410 B onset: None C onset: None
# file complete OA29_Freq 151.wav : the castle and the horn or below the knife Speech onset: 3709 A onset: None B onset: None C onset: None
# file complete OA29_Freq 153.wav : the cran and the spoon or below the glass Speech onset: 1929 A onset: None B onset: 1980 C onset: 2820
# file complete OA29_Freq 154.wav : the newspaper and the capital are below the purse Speech onset: 1551 A onset: 1620 B onset: None C onset: None
# file complete OA29_Freq 156.wav : the crab and the boot or above the card Speech onset: 1638 A onset: None B onset: 1590 C onset: 2370
# file complete OA29_Freq 158.wav : the necklace and the the time tunnel or above the beach Speech onset: 6569 A onset: 13470 B onset: 6660 C onset: None
# file complete OA29_Rel 2.wav : the cat and the tie above the dog another dog is below the cat and tie Speech onset: 2003 A onset: 3360 B onset: 1950 C onset: 2490
# file complete OA29_Rel 8.wav : the girl is above the boy and the money Speech onset: 1310 A onset: 1410 B onset: 2550 C onset: 4170
# file complete OA29_Rel 10.wav : the doctor is above the hospital and the newspaper Speech onset: 1607 A onset: 1710 B onset: 3090 C onset: 3990
# file complete OA29_Rel 13.wav : the door and the window are below the keyboard Speech onset: 1395 A onset: 1530 B onset: 2340 C onset: 3870
# file complete OA29_Rel 16.wav : the shirt and the pants are above the key Speech onset: 1860 A onset: 1950 B onset: 2492 C onset: 3630
# file complete OA29_Rel 21.wav : the bed is below the pillow and the truck Speech onset: 1385 A onset: 1470 B onset: 2700 C onset: 3540
# file complete OA29_Rel 30.wav : the baby is above baby bed and the castle Speech onset: 1514 A onset: 1590 B onset: None C onset: 5430
# file complete OA29_Rel 33.wav : the gun and the canon or below the tie Speech onset: 1284 A onset: 1410 B onset: None C onset: 3030
# file complete OA29_Rel 34.wav : the honey and the bee or below cut the king's chair whatever Speech onset: 2170 A onset: 2250 B onset: 3030 C onset: None
# file complete OA29_Rel 38.wav : the horse and the camel are above the stethoscope Speech onset: 1779 A onset: 1860 B onset: 2490 C onset: 3690
# file complete OA29_Rel 41.wav : the anchor is below wish the that shit and the crib Speech onset: 3199 A onset: 3270 B onset: 9390 C onset: 11910
# file complete OA29_Rel 43.wav : the skirt is below the dress and the frog Speech onset: 1387 A onset: 1350 B onset: 2640 C onset: 3330
# file complete OA29_Rel 47.wav : the throne is above the king and the pan Speech onset: 1284 A onset: 1350 B onset: 2699 C onset: 3630
# file complete OA29_Rel 53.wav : the comb and the hair is below the bus Speech onset: 1999 A onset: 2700 B onset: 4740 C onset: 6960
# file complete OA29_Rel 59.wav : the nest and the bird are above the hangar Speech onset: 1639 A onset: 1770 B onset: 2400 C onset: 3450
# file complete OA29_Rel 65.wav : the giraffe is below the zebra and the cup Speech onset: 1889 A onset: 1980 B onset: 3630 C onset: None
# file complete OA29_Rel 66.wav : the hammer is above the nail and the fish Speech onset: 1542 A onset: 1590 B onset: 2670 C onset: 3450
# file complete OA29_Rel 72.wav : the sheep and the good or below the door Speech onset: 2252 A onset: 2370 B onset: None C onset: None
# file complete OA29_Rel 76.wav : the arrow and the dark or above the comb Speech onset: 1822 A onset: 1800 B onset: 2670 C onset: 4320
# file complete OA29_Rel 80.wav : the scarf and mittens are above the horse gloves or whatever Speech onset: 2197 A onset: 2310 B onset: 3660 C onset: 4980
# file complete OA29_Rel 81.wav : it was a diagonal think of was diagonal actually the beach is below the tie and the fork Speech onset: 85 A onset: 5610 B onset: 6810 C onset: 7470
# file complete OA29_Rel 87.wav : the key is above the flower and the cat i can't Speech onset: 1295 A onset: 1380 B onset: None C onset: None
# file complete OA29_Rel 88.wav : the table is above the doctor and the camel Speech onset: 1092 A onset: 1170 B onset: 2460 C onset: 3390
# file complete OA29_Rel 92.wav : the leg and the ring or below the broom Speech onset: 1620 A onset: 1740 B onset: 2400 C onset: 3630
# file complete OA29_Rel 96.wav : the clock or but the zebra Speech onset: 1560 A onset: None B onset: None C onset: None
# file complete OA29_Rel 105.wav : the church is below the dart and the headphones Speech onset: 2476 A onset: 2580 B onset: 5670 C onset: 6629
# file complete OA29_Rel 106.wav : the bed is above the frog and the broom Speech onset: 1219 A onset: 1320 B onset: 2490 C onset: None
# file complete OA29_Rel 112.wav : the sun and the broom or below the house Speech onset: 1796 A onset: 1920 B onset: 2880 C onset: 4590
# file complete OA29_Rel 115.wav : the hospital and lightning are below the elephant Speech onset: 1957 A onset: 2040 B onset: 5310 C onset: 6930
# file complete OA29_Rel 118.wav : the bridge and the wallet are above the spoon Speech onset: 2076 A onset: 2160 B onset: 3000 C onset: 4440
# file complete OA29_Rel 123.wav : the cave is above below the nose and the gun Speech onset: 2429 A onset: 2490 B onset: 4560 C onset: 5400
# file complete OA29_Rel 125.wav : the nest is below the ice and the crown Speech onset: 3044 A onset: 3180 B onset: 4380 C onset: 5040
# file complete OA29_Rel 129.wav : the crab is the the pants and the angel Speech onset: 1903 A onset: 1740 B onset: 4019 C onset: 5130
# file complete OA29_Rel 131.wav : the hammer and the chair are below the dog Speech onset: 1671 A onset: 1800 B onset: 2670 C onset: 4140
# file complete OA29_Rel 136.wav : the mittens and the cake are above the briefcase Speech onset: 1922 A onset: 2070 B onset: 2760 C onset: 3870
# file complete OA29_Rel 144.wav : the vases below the skirt and the computer Speech onset: 2080 A onset: 2220 B onset: 3510 C onset: 4350
# file complete OA29_Rel 150.wav : the b is above the scarf and the canon Speech onset: 1077 A onset: None B onset: 1170 C onset: 2040
# file complete OA29_Rel 155.wav : the zebra and the helicopter are below the sun Speech onset: 1805 A onset: 1830 B onset: 2580 C onset: 4380
# file complete OA29_Rel 157.wav : the pillow and the sink or above the tree Speech onset: 1392 A onset: 1500 B onset: 2910 C onset: 4440
# file complete OA29_Rel 160.wav : the whale and the acorn are above the clock Speech onset: 2416 A onset: 2490 B onset: 3180 C onset: 4500
# file complete YA102_Freq 83.wav : the coat and the money above the lizard Speech onset: 1195 A onset: 1320 B onset: 1770 C onset: 2400
# file complete YA102_Freq 85.wav : the radio and the nurse are about the dominoes Speech onset: 554 A onset: 2490 B onset: 3420 C onset: 4140
# file complete YA102_Freq 86.wav : the house and the wallet are hosting the wachovia now Speech onset: 1146 A onset: 1440 B onset: None C onset: None
# file complete YA102_Freq 89.wav : the gun and the dusk or beneath the honey Speech onset: 658 A onset: 1170 B onset: 1770 C onset: 2700
# file complete YA102_Freq 90.wav : the fire and the tape or beneath the necklace Speech onset: 1135 A onset: 1230 B onset: 1740 C onset: 2459
# file complete YA102_Freq 93.wav : the shirt is above the dog and the dust Speech onset: 1365 A onset: 2130 B onset: 3510 C onset: None
# file complete YA102_Freq 94.wav : the book is above the the star Speech onset: 515 A onset: 1020 B onset: None C onset: None
# file complete YA102_Freq 97.wav : the tickets are beneath the fish and the balloon Speech onset: 1187 A onset: 1470 B onset: 2400 C onset: 2820
# file complete YA102_Freq 99.wav : the doors beneath the computer and the pirate ship Speech onset: 673 A onset: 1050 B onset: 1770 C onset: 2640
# file complete YA102_Freq 100.wav : the bird is beneath the school and the water Speech onset: 1128 A onset: 1350 B onset: 2250 C onset: 2850
# file complete YA102_Freq 101.wav : the pool and the stapler above the goat Speech onset: 921 A onset: 1050 B onset: 1410 C onset: 2190
# file complete YA102_Freq 102.wav : the foot and the pills are above the skirt Speech onset: 1250 A onset: 1380 B onset: 1860 C onset: 2610
# file complete YA102_Freq 103.wav : the slipper blow the trumpet Speech onset: 1079 A onset: None B onset: None C onset: None
# file complete YA102_Freq 109.wav : the kitchen and the gutter beneath the hand Speech onset: 1258 A onset: 1350 B onset: None C onset: None
# file complete YA102_Freq 110.wav : the saw on the leaf or beneath the book Speech onset: 1130 A onset: 1262 B onset: 1650 C onset: 2370
# file complete YA102_Freq 111.wav : the mystic is above the hangar and the shovel Speech onset: 879 A onset: None B onset: None C onset: None
# file complete YA102_Freq 114.wav : the the dress is about the yard and the bottle Speech onset: 1450 A onset: 1950 B onset: 3030 C onset: 3450
# file complete YA102_Freq 117.wav : the buses beneath the hippo and the like Speech onset: 867 A onset: None B onset: 960 C onset: 2940
# file complete YA102_Freq 119.wav : the road is beneath the tub and the scissors Speech onset: 1516 A onset: 1710 B onset: None C onset: 2670
# file complete YA102_Freq 120.wav : the horses beneath the balloon and the church Speech onset: 519 A onset: 930 B onset: 1710 C onset: 2250
# file complete YA102_Freq 121.wav : the face and the cat are both the strawberry Speech onset: 2013 A onset: None B onset: None C onset: None
# file complete YA102_Freq 122.wav : the scissors and the tree are above the baby Speech onset: 1089 A onset: 1200 B onset: 1830 C onset: 2520
# file complete YA102_Freq 126.wav : the shove on the car beneath the well Speech onset: 999 A onset: None B onset: None C onset: None
# file complete YA102_Freq 127.wav : the fork and the fedora beneath the pills Speech onset: 820 A onset: 930 B onset: None C onset: None
# file complete YA102_Freq 130.wav : the mop and the harder beneath the acorn Speech onset: 1189 A onset: 1380 B onset: None C onset: None
# file complete YA102_Freq 132.wav : the skirt is above the plane and the cave Speech onset: 975 A onset: 1140 B onset: 1950 C onset: 2430
# file complete YA102_Freq 133.wav : the arrows above the train and the dusk Speech onset: 918 A onset: 1080 B onset: 2130 C onset: 2640
# file complete YA102_Freq 134.wav : the lamp is above the angel and the hippo Speech onset: 946 A onset: 1080 B onset: 1830 C onset: 2310
# file complete YA102_Freq 137.wav : the lizard is beneath the truck and the harp Speech onset: 663 A onset: 1710 B onset: 2760 C onset: 3180
# file complete YA102_Freq 139.wav : the pen is beneath the ring and the basket Speech onset: 1326 A onset: 1260 B onset: 2190 C onset: 2580
# file complete YA102_Freq 141.wav : the anchor and the basket above the pair Speech onset: 1020 A onset: 1140 B onset: 1530 C onset: None
# file complete YA102_Freq 142.wav : the grass and the sheep are both the land Speech onset: 1051 A onset: 1140 B onset: 1710 C onset: None
# file complete YA102_Freq 143.wav : the seal and the or both of the hospital Speech onset: 1274 A onset: 1380 B onset: None C onset: None
# file complete YA102_Freq 146.wav : the thrown on them nail or beneath the car Speech onset: 1079 A onset: None B onset: None C onset: None
# file complete YA102_Freq 147.wav : the elephant and the dominoes are beneath the tape Speech onset: 378 A onset: 1410 B onset: 1980 C onset: 2851
# file complete YA102_Freq 151.wav : the sand castle is above the trumpet and the knife Speech onset: 1153 A onset: None B onset: 1262 C onset: 2490
# file complete YA102_Freq 153.wav : the crowns of both the spoon and the glass Speech onset: 938 A onset: 1050 B onset: 1860 C onset: 2340
# file complete YA102_Freq 154.wav : the paper is above the camel on the satchel Speech onset: 910 A onset: None B onset: 990 C onset: 1950
# file complete YA102_Freq 156.wav : the lobsters beneath the boot the card Speech onset: 971 A onset: 1110 B onset: 2040 C onset: 2400
# file complete YA102_Freq 158.wav : the tunnel is beneath the necklace and to be Speech onset: 723 A onset: 1530 B onset: 3060 C onset: None
# file complete YA102_Rel 2.wav : the dog and the cat are both Speech onset: 1075 A onset: 1140 B onset: 1560 C onset: None
# file complete YA102_Rel 8.wav : the girl and the boy are beneath the money Speech onset: 1501 A onset: 1620 B onset: 2460 C onset: 3480
# file complete YA102_Rel 10.wav : the dude and the hospital or beneath the paper Speech onset: 1839 A onset: None B onset: None C onset: None
# file complete YA102_Rel 13.wav : the door is above the window and the keyboard Speech onset: 1153 A onset: 1260 B onset: 2280 C onset: 2850
# file complete YA102_Rel 16.wav : the shirt is beneath the jeans and the key Speech onset: 1525 A onset: 1650 B onset: None C onset: 3030
# file complete YA102_Rel 21.wav : the bed and the pillow or above the truck Speech onset: 1047 A onset: 1230 B onset: 1619 C onset: 2520
# file complete YA102_Rel 30.wav : the baby and the crib or beneath the castle Speech onset: 1157 A onset: 1260 B onset: 2009 C onset: None
# file complete YA102_Rel 33.wav : the gun is about the kind and a tie Speech onset: 896 A onset: 990 B onset: None C onset: None
# file complete YA102_Rel 34.wav : the honey is above the b and the chair Speech onset: 0 A onset: 1170 B onset: None C onset: 2100
# file complete YA102_Rel 38.wav : the forces beneath the camel and the stethoscope Speech onset: 723 A onset: None B onset: None C onset: 1290
# file complete YA102_Rel 41.wav : the anchor and the ship are both the button Speech onset: 986 A onset: 1110 B onset: 1560 C onset: None
# file complete YA102_Rel 43.wav : the skirt and the dress are above the frog Speech onset: 902 A onset: 1020 B onset: 1650 C onset: 2430
# file complete YA102_Rel 47.wav : the the chair and the king are beneath the pan Speech onset: 1582 A onset: None B onset: 2670 C onset: 3750
# file complete YA102_Rel 53.wav : the comb is above the hair on the bus Speech onset: 763 A onset: 870 B onset: 1650 C onset: 2100
# file complete YA102_Rel 59.wav : the nest is beneath the beard and the hangar Speech onset: 1365 A onset: 1920 B onset: None C onset: None
# file complete YA102_Rel 65.wav : the giraffe zebra above the mug Speech onset: 1283 A onset: 1440 B onset: 1950 C onset: 2730
# file complete YA102_Rel 66.wav : the hammer and the nail or beneath the fish Speech onset: 780 A onset: 1080 B onset: 1560 C onset: 2220
# file complete YA102_Rel 72.wav : the sheep is above the goat and the door Speech onset: 950 A onset: 1050 B onset: 1950 C onset: 2399
# file complete YA102_Rel 76.wav : the arrow is beneath the dart and the comb Speech onset: 1148 A onset: 1500 B onset: 2760 C onset: 3300
# file complete YA102_Rel 80.wav : the scarf has beneath the mittens and the horse Speech onset: 1034 A onset: 2040 B onset: 3480 C onset: 4080
# file complete YA102_Rel 81.wav : the beach and the tire above Speech onset: 2102 A onset: 3120 B onset: None C onset: 3960
# file complete YA102_Rel 87.wav : the key and the rows are beneath the cat Speech onset: 1155 A onset: 1260 B onset: None C onset: 1920
# file complete YA102_Rel 88.wav : the table and the dude are being the camel Speech onset: 1321 A onset: 1440 B onset: None C onset: None
# file complete YA102_Rel 92.wav : the leg is above the ring and the broom Speech onset: 1048 A onset: 1230 B onset: 2820 C onset: 3451
# file complete YA102_Rel 96.wav : the coat is beneath the clock and the zebra Speech onset: 1337 A onset: None B onset: 1470 C onset: 2460
# file complete YA102_Rel 105.wav : the church and the dark or above the headphones Speech onset: 836 A onset: 1170 B onset: 1860 C onset: 2820
# file complete YA102_Rel 106.wav : the bed and the frog are beneath the rake Speech onset: 1302 A onset: 1410 B onset: 2070 C onset: 3420
# file complete YA102_Rel 112.wav : the sun is above the room and the house Speech onset: 929 A onset: 1020 B onset: None C onset: None
# file complete YA102_Rel 115.wav : the hospital was above the lightning and the elephant Speech onset: 833 A onset: 960 B onset: 2009 C onset: 2940
# file complete YA102_Rel 118.wav : the bridge is beneath the wallet and the spoon Speech onset: 960 A onset: 1110 B onset: 1980 C onset: 2520
# file complete YA102_Rel 123.wav : the cave and the nose or above the gun Speech onset: 815 A onset: 1380 B onset: 2040 C onset: 3150
# file complete YA102_Rel 125.wav : the nurse and the ice both the crown Speech onset: 1094 A onset: None B onset: None C onset: None
# file complete YA102_Rel 129.wav : the crab and the jeans are beneath the angel Speech onset: 1559 A onset: 1680 B onset: None C onset: 2460
# file complete YA102_Rel 131.wav : the hammer is above the chair and the dog Speech onset: 804 A onset: 1140 B onset: 1950 C onset: 2490
# file complete YA102_Rel 136.wav : the gloves are beneath the cake and the briefcase Speech onset: 1377 A onset: None B onset: None C onset: None
# file complete YA102_Rel 144.wav : the face and the skirt are above the monitor Speech onset: 970 A onset: None B onset: 1170 C onset: 2670
# file complete YA102_Rel 150.wav : the b and the scarf or beneath the canon Speech onset: 1225 A onset: None B onset: 1320 C onset: 1680
# file complete YA102_Rel 155.wav : the zebra is about the helicopter and the sun Speech onset: 853 A onset: 960 B onset: 2009 C onset: 2790
# file complete YA102_Rel 157.wav : the pillow is beneath the sink and the tree Speech onset: 1283 A onset: 1440 B onset: 2610 C onset: 3150
# file complete YA102_Rel 160.wav : the wheels beneath the acorn the clock Speech onset: 1177 A onset: None B onset: 1290 C onset: 2100
# file complete YA86_Freq 83.wav : the code is above the money and the lizard Speech onset: 2223 A onset: None B onset: None C onset: 2100
# file complete YA86_Freq 85.wav : the radio is above the nurse and the dominance Speech onset: 2731 A onset: 3120 B onset: 4770 C onset: None
# file complete YA86_Freq 86.wav : the house is below the watch and then they don't Speech onset: 1286 A onset: 1410 B onset: 3510 C onset: None
# file complete YA86_Freq 89.wav : the gun is below the desk and the honey Speech onset: 1392 A onset: 1500 B onset: 2490 C onset: 3450
# file complete YA86_Freq 90.wav : the fire is below the tape and the necklace Speech onset: 1293 A onset: 1200 B onset: 2550 C onset: 3570
# file complete YA86_Freq 93.wav : the shirt and the dog are above the table Speech onset: 2227 A onset: 2340 B onset: 3180 C onset: 4530
# file complete YA86_Freq 94.wav : the book and the hair are above the star Speech onset: 1777 A onset: 1980 B onset: 3330 C onset: 4788
# file complete YA86_Freq 97.wav : the tickets and the fish are below the balloon Speech onset: 1699 A onset: 1590 B onset: 2250 C onset: 3840
# file complete YA86_Freq 99.wav : the door and the computer are below the ship Speech onset: 1197 A onset: 1380 B onset: 2009 C onset: 3660
# file complete YA86_Freq 100.wav : the bird and the school are below the jaw Speech onset: 2076 A onset: 2310 B onset: 3784 C onset: None
# file complete YA86_Freq 101.wav : the pool is above the steeper and the goat Speech onset: 1225 A onset: 1350 B onset: None C onset: None
# file complete YA86_Freq 102.wav : the foot is above the pills and the skirt Speech onset: 1406 A onset: 1230 B onset: 2610 C onset: 3306
# file complete YA86_Freq 103.wav : the bear is above the sandal and the trumpet Speech onset: 1098 A onset: 1320 B onset: 2670 C onset: 4350
# file complete YA86_Freq 109.wav : the kitchen is below the goats and the hammer Speech onset: 1518 A onset: 1650 B onset: 3570 C onset: 4320
# file complete YA86_Freq 110.wav : the assault is below the leaf and the book Speech onset: 3259 A onset: None B onset: None C onset: None
# file complete YA86_Freq 111.wav : the stick and the hangar are above the shovel Speech onset: 1449 A onset: 1530 B onset: 2070 C onset: 4620
# file complete YA86_Freq 114.wav : the dress and the yarn are above the bottom Speech onset: 1460 A onset: 1590 B onset: 2310 C onset: None
# file complete YA86_Freq 117.wav : the bus and the hippo are below the leg Speech onset: 1667 A onset: 1740 B onset: 2400 C onset: 4440
# file complete YA86_Freq 119.wav : the road and the bathtub or below the scissors Speech onset: 2926 A onset: 3063 B onset: 5010 C onset: 6930
# file complete YA86_Freq 120.wav : the horse and the balloon are below the trick Speech onset: 1269 A onset: 1440 B onset: 2280 C onset: None
# file complete YA86_Freq 121.wav : the best is about the cat and the strawberry Speech onset: 1174 A onset: 1290 B onset: 2430 C onset: 3330
# file complete YA86_Freq 122.wav : the scissors are above the tree and the baby Speech onset: 1126 A onset: 1320 B onset: 3660 C onset: 4440
# file complete YA86_Freq 126.wav : the shovel is below the card and the whale Speech onset: 2086 A onset: 2190 B onset: 3480 C onset: 4260
# file complete YA86_Freq 127.wav : the fork is below the hat and pills Speech onset: 2030 A onset: 1890 B onset: 3420 C onset: 4272
# file complete YA86_Freq 130.wav : the mall is below the heart and the acre Speech onset: 2739 A onset: None B onset: None C onset: None
# file complete YA86_Freq 132.wav : the skirt and the plane are above the cave Speech onset: 1189 A onset: 1500 B onset: 2280 C onset: 3810
# file complete YA86_Freq 133.wav : the arrow and the train are above the desk Speech onset: 1775 A onset: 2009 B onset: 3060 C onset: 4620
# file complete YA86_Freq 134.wav : the lamp and the angel above the hip though Speech onset: 1356 A onset: 1440 B onset: 2190 C onset: None
# ...
# file complete YA87_Freq 89.wav : the gun is above the desk and the honey Speech onset: 993 A onset: 1080 B onset: 2310 C onset: 3000
# file complete YA87_Freq 90.wav : the fires above the tape and the necklace Speech onset: 719 A onset: 840 B onset: 2460 C onset: 3089
# file complete YA87_Freq 93.wav : the shirt and the dog are below the table Speech onset: 1458 A onset: 1560 B onset: 2160 C onset: 2910
# file complete YA87_Freq 94.wav : the book and the hair below the star Speech onset: 1133 A onset: 1230 B onset: 1800 C onset: 2580
# file complete YA87_Freq 97.wav : the ticket and the fish are above the balloon Speech onset: 1084 A onset: 1440 B onset: 2070 C onset: 3180
# file complete YA87_Freq 99.wav : the door and the computer about the ship Speech onset: 1163 A onset: 1290 B onset: 1830 C onset: 2820
# file complete YA87_Freq 100.wav : the third and the school or about the water Speech onset: 991 A onset: None B onset: None C onset: None
# file complete YA87_Freq 101.wav : the pool is below the stapler and the goat Speech onset: 1518 A onset: 1650 B onset: 2850 C onset: 3720
# file complete YA87_Freq 102.wav : the foot is below the pills and skirt Speech onset: 1571 A onset: 1770 B onset: 3180 C onset: 3690
# file complete YA87_Freq 103.wav : the bears below the slipper and the trumpet Speech onset: 971 A onset: 1294 B onset: None C onset: 2430
# file complete YA87_Freq 109.wav : the kitchen is above the goat and the hammer Speech onset: 1498 A onset: 1590 B onset: 2850 C onset: 3330
# file complete YA87_Freq 110.wav : the song is about the leaf and the book Speech onset: 1336 A onset: None B onset: None C onset: None
# file complete YA87_Freq 111.wav : the stick on the hangar below the shovel Speech onset: 1188 A onset: 1290 B onset: 1920 C onset: 2820
# file complete YA87_Freq 114.wav : the dress and the yarn are below the bottom Speech onset: 1242 A onset: 1410 B onset: 2070 C onset: None
# file complete YA87_Freq 117.wav : the bus and the hippo or about the leg Speech onset: 1424 A onset: 1500 B onset: 2100 C onset: 3090
# file complete YA87_Freq 119.wav : the road and the bathtub or above the scissors Speech onset: 1065 A onset: 1200 B onset: 2370 C onset: 4380
# file complete YA87_Freq 120.wav : the forest and the balloon or about the church Speech onset: 804 A onset: None B onset: None C onset: None
# file complete YA87_Freq 121.wav : the best is below the cat and the strawberry Speech onset: 1636 A onset: 2009 B onset: 3060 C onset: 3840
# file complete YA87_Freq 122.wav : the scissors are below the tree and the baby Speech onset: 1150 A onset: 1230 B onset: 2160 C onset: 2760
# file complete YA87_Freq 126.wav : shovel is above the card and the wheel Speech onset: 875 A onset: 1120 B onset: 2310 C onset: None
# file complete YA87_Freq 127.wav : the fork is about the hat and the pills Speech onset: 684 A onset: 990 B onset: 1920 C onset: 2370
# file complete YA87_Freq 130.wav : the mop is above the heart and the equipment Speech onset: 1794 A onset: 2009 B onset: 3060 C onset: None
# file complete YA87_Freq 132.wav : the skirt and the plane are below the cave Speech onset: 1104 A onset: 1200 B onset: 1830 C onset: 2730
# file complete YA87_Freq 133.wav : the arrow and the trainer beloved the desk Speech onset: 1125 A onset: 1920 B onset: None C onset: 2430
# file complete YA87_Freq 134.wav : the lamp and the anger are below the hip Speech onset: 1241 A onset: 1350 B onset: 1950 C onset: None
# file complete YA87_Freq 137.wav : the lizard and the truck i bought the harp Speech onset: 1166 A onset: 1530 B onset: 2160 C onset: 3030
# file complete YA87_Freq 139.wav : the pen and the ring are above the basket Speech onset: 790 A onset: 960 B onset: 1530 C onset: 2430
# file complete YA87_Freq 141.wav : the anchors below the basket and the pair Speech onset: 1010 A onset: 1110 B onset: 2100 C onset: None
# file complete YA87_Freq 142.wav : the grass is below the sheep and the lamp Speech onset: 1104 A onset: 1170 B onset: 2160 C onset: 2970
# file complete YA87_Freq 143.wav : the seal is below the rake and the hospital Speech onset: 1130 A onset: 1080 B onset: 2009 C onset: 2520
# file complete YA87_Freq 146.wav : the chair is above the kneel and the car Speech onset: 1163 A onset: None B onset: 1500 C onset: None
# file complete YA87_Freq 147.wav : the elephant is above the dominoes and the team Speech onset: 1099 A onset: 1140 B onset: 2100 C onset: None
# file complete YA87_Freq 151.wav : the sand castle and the trumpet are below the knife Speech onset: 1301 A onset: None B onset: 1410 C onset: 2430
# file complete YA87_Freq 153.wav : the crone and the spoon or below the glass Speech onset: 1252 A onset: None B onset: None C onset: None
# file complete YA87_Freq 154.wav : the newspaper and the camel are below the purse Speech onset: 1305 A onset: 1410 B onset: 2430 C onset: 3330
# file complete YA87_Freq 156.wav : the lobster and the boot pair up on the cards Speech onset: 1104 A onset: 2700 B onset: 4050 C onset: 5520
# file complete YA87_Freq 158.wav : the tunnel and the new clothes are about to be Speech onset: 1317 A onset: 1440 B onset: None C onset: 2100
# file complete YA87_Rel 2.wav : the dog is below the cat and the tie Speech onset: 1933 A onset: 2040 B onset: 3180 C onset: 4050
# file complete YA87_Rel 8.wav : the girl is above the boy and the money Speech onset: 1576 A onset: 1650 B onset: 2790 C onset: 3360
# file complete YA87_Rel 10.wav : the doctor is about the hospital and the newspaper Speech onset: 1128 A onset: 1230 B onset: 2340 C onset: 3270
# file complete YA87_Rel 13.wav : the door and the windows are below the keyboard Speech onset: 1970 A onset: 2400 B onset: 2970 C onset: 3990
# file complete YA87_Rel 16.wav : the shirt and the pants are above the key Speech onset: 2133 A onset: 2250 B onset: 3120 C onset: 4530
# file complete YA87_Rel 21.wav : the bed is below the pillow and the truck Speech onset: 1039 A onset: 1560 B onset: 2460 C onset: 3210
# file complete YA87_Rel 30.wav : the baby is above the crib and the sand castle Speech onset: 2153 A onset: 2340 B onset: 3780 C onset: None
# file complete YA87_Rel 33.wav : the gun and the cannon are below the tie Speech onset: 1165 A onset: 1530 B onset: 2040 C onset: 3180
# file complete YA87_Rel 34.wav : the honey and the bee are below the chair Speech onset: 1790 A onset: 1920 B onset: 2640 C onset: None
# file complete YA87_Rel 38.wav : the horse and the camel or about the stethoscope Speech onset: 1592 A onset: 1680 B onset: 2190 C onset: 3150
# file complete YA87_Rel 41.wav : the anchor is below the ship and the crib Speech onset: 1805 A onset: 1920 B onset: 3060 C onset: 4110
# file complete YA87_Rel 43.wav : the skirt is below the dress and the frog Speech onset: 951 A onset: 1081 B onset: 2100 C onset: 2640
# file complete YA87_Rel 47.wav : the chair is above the king and the pen Speech onset: 2098 A onset: None B onset: 2220 C onset: 3480
# file complete YA87_Rel 53.wav : the comb and hair are above but below the bus Speech onset: 1247 A onset: 1320 B onset: 2460 C onset: 3510
# file complete YA87_Rel 59.wav : the nest and the bird are above the hang Speech onset: 1644 A onset: 1770 B onset: 2460 C onset: None
# file complete YA87_Rel 65.wav : the giraffe is below the zebra and the cup Speech onset: 940 A onset: 1530 B onset: 2640 C onset: None
# file complete YA87_Rel 66.wav : the humor is above the nail and the fish Speech onset: 1060 A onset: None B onset: 1170 C onset: 2220
# file complete YA87_Rel 72.wav : the sheep and the goat are below beloved door Speech onset: 1230 A onset: 1560 B onset: 2100 C onset: 3324
# file complete YA87_Rel 76.wav : the arrow and the dark or about the comb Speech onset: 1151 A onset: 1530 B onset: 2160 C onset: 3030
# file complete YA87_Rel 80.wav : the scarf and mittens are above the horse Speech onset: 1260 A onset: 1380 B onset: 1950 C onset: 2940
# file complete YA87_Rel 81.wav : the beach is below the tie and the fork Speech onset: 2060 A onset: 2160 B onset: 3390 C onset: 3960
# file complete YA87_Rel 87.wav : the key is above the rose and the cat Speech onset: 1009 A onset: 1080 B onset: 2009 C onset: 2430
# file complete YA87_Rel 88.wav : the table is above the police and the camel Speech onset: 1175 A onset: 1500 B onset: None C onset: None
# file complete YA87_Rel 92.wav : the leg and the ring or below the broom Speech onset: 1136 A onset: 1260 B onset: 2730 C onset: 3810
# file complete YA87_Rel 96.wav : the suit and the clock are above the zebra Speech onset: 2106 A onset: 2370 B onset: 4200 C onset: 5160
# file complete YA87_Rel 105.wav : the church is below the dirt and the headphones Speech onset: 2011 A onset: 2130 B onset: 3330 C onset: 3840
# file complete YA87_Rel 106.wav : the bed is above the frog and reek Speech onset: 1999 A onset: 2130 B onset: 3180 C onset: None
# file complete YA87_Rel 112.wav : the sun and the broom or below the house Speech onset: 1200 A onset: 1320 B onset: 1770 C onset: 4290
# file complete YA87_Rel 115.wav : the hospital and lightning are below the elephant Speech onset: 1679 A onset: 1800 B onset: 2670 C onset: 4140
# file complete YA87_Rel 118.wav : the bridge and the wallet are about the spoon Speech onset: 1114 A onset: 1470 B onset: 2430 C onset: 3300
# file complete YA87_Rel 123.wav : the cave is below the nose and the gun Speech onset: 1932 A onset: 2370 B onset: 3360 C onset: 3965
# file complete YA87_Rel 125.wav : the nest is below the ice and the crown Speech onset: 902 A onset: 1380 B onset: 2280 C onset: 2850
# file complete YA87_Rel 129.wav : the crap is above the pants and the angel Speech onset: 1107 A onset: 1170 B onset: 2220 C onset: 2790
# file complete YA87_Rel 131.wav : the hammer and the chair below the dog Speech onset: 1071 A onset: 1170 B onset: 1680 C onset: 2640
# file complete YA87_Rel 136.wav : the mittens and the cake are above the briefcase Speech onset: 993 A onset: 1350 B onset: 1980 C onset: 3630
# file complete YA87_Rel 144.wav : the base is below the skirt and the computer Speech onset: 1169 A onset: 1500 B onset: 2730 C onset: 5550
# file complete YA87_Rel 150.wav : the bee is above the scarf and the cannon Speech onset: 1569 A onset: 2640 B onset: 4860 C onset: 5640
# file complete YA87_Rel 155.wav : the zebra and the helicopter below the sun Speech onset: 1202 A onset: 1103 B onset: 2130 C onset: 3210
# file complete YA87_Rel 157.wav : the pillow and the sink or about the tree Speech onset: 2290 A onset: 2130 B onset: 2940 C onset: 3810
# file complete YA87_Rel 160.wav : the whale and a corner about the clock Speech onset: 1023 A onset: 1380 B onset: None C onset: 2160
# file complete YA98_Rel 2.wav : the dog is above the cat and a tie Speech onset: 1437 A onset: 1560 B onset: 2820 C onset: 3510
# file complete YA98_Rel 8.wav : the girl is below the boy and the money Speech onset: 1037 A onset: 1110 B onset: 2160 C onset: 2760
# file complete YA98_Rel 10.wav : the doctor is below the hospital and the newspaper Speech onset: 1397 A onset: 1500 B onset: 2640 C onset: 3450
# file complete YA98_Rel 13.wav : the door and the window are about the keyboard Speech onset: 837 A onset: 960 B onset: 1530 C onset: 2580
# file complete YA98_Rel 16.wav : the shirt and the pants are below the key Speech onset: 1907 A onset: 1980 B onset: 2730 C onset: 3780
# file complete YA98_Rel 21.wav : the bed is above the pillow and the truck Speech onset: 991 A onset: 1050 B onset: 2040 C onset: 2640
# file complete YA98_Rel 30.wav : the baby is below the crib and the castle Speech onset: 992 A onset: 1110 B onset: 2460 C onset: None
# file complete YA98_Rel 33.wav : the gun and the cannon are above the tie Speech onset: 1051 A onset: 1140 B onset: 1710 C onset: 2880
# file complete YA98_Rel 34.wav : the honey and the bee are above the certain Speech onset: 1418 A onset: 1500 B onset: 3060 C onset: None
# file complete YA98_Rel 38.wav : the horse and the camel or below the stethoscope Speech onset: 930 A onset: 1020 B onset: 1530 C onset: 2400
# file complete YA98_Rel 41.wav : the anchor is above the ship and the crib Speech onset: 1022 A onset: 1140 B onset: 2280 C onset: 2880
# file complete YA98_Rel 43.wav : the skirt is above the dress and the frock Speech onset: 1009 A onset: 1020 B onset: 2040 C onset: None
# file complete YA98_Rel 47.wav : the throne is below the king and the pan Speech onset: 1229 A onset: 1320 B onset: 2610 C onset: 3510
# file complete YA98_Rel 53.wav : the comb and the hair above the bus Speech onset: 1014 A onset: 1110 B onset: 1830 C onset: 2790
# file complete YA98_Rel 59.wav : the nest and the bird are below the hangar Speech onset: 1436 A onset: 1560 B onset: 2160 C onset: 3330
# file complete YA98_Rel 65.wav : the giraffe is above the zebra and the cup Speech onset: 903 A onset: 990 B onset: 2100 C onset: None
# file complete YA98_Rel 66.wav : the hammer is above below the nail and the fish Speech onset: 1242 A onset: 1350 B onset: 3900 C onset: 4620
# file complete YA98_Rel 72.wav : the sheep and the goat or above the door Speech onset: 914 A onset: 990 B onset: 1620 C onset: 2460
# file complete YA98_Rel 76.wav : the arrow and the dar are below the comb Speech onset: 1217 A onset: 1380 B onset: None C onset: 2460
# file complete YA98_Rel 80.wav : the scarf and mittens are below the horse Speech onset: 1097 A onset: 1200 B onset: 1830 C onset: 2850
# file complete YA98_Rel 81.wav : the beach is above the tie and the fork Speech onset: 1627 A onset: 1860 B onset: 3240 C onset: 3810
# file complete YA98_Rel 87.wav : the key is below the rose and the cat Speech onset: 998 A onset: 1080 B onset: 2009 C onset: 2580
# file complete YA98_Rel 88.wav : the table is below the doctor and the camel Speech onset: 1367 A onset: 1470 B onset: 2610 C onset: 3210
# file complete YA98_Rel 92.wav : the leg and the ring are above the room Speech onset: 1097 A onset: 1200 B onset: 1800 C onset: None
# file complete YA98_Rel 96.wav : the shoe and the clock our beloved zebra Speech onset: 1444 A onset: None B onset: None C onset: None
# file complete YA98_Rel 105.wav : the church is above the dart and the headphones Speech onset: 1330 A onset: 1440 B onset: 2460 C onset: 2970
# file complete YA98_Rel 106.wav : the bird is below the frog and the ring Speech onset: 1336 A onset: None B onset: None C onset: None
# file complete YA98_Rel 112.wav : the side of the room or above the house Speech onset: 903 A onset: None B onset: None C onset: None
# file complete YA98_Rel 115.wav : the hospital and the lightning are above the elephant Speech onset: 1130 A onset: 1230 B onset: 2009 C onset: 3121
# file complete YA98_Rel 118.wav : the bridge and the wallet are below the spit Speech onset: 1057 A onset: 1140 B onset: 2190 C onset: None
# file complete YA98_Rel 123.wav : the cave is above the nose and the gun Speech onset: 1172 A onset: 1260 B onset: 2310 C onset: 2910
# file complete YA98_Rel 125.wav : the nest is above the ice and the crown Speech onset: 1220 A onset: 1320 B onset: 2460 C onset: 3030
# file complete YA98_Rel 129.wav : the crab is below the pants and the angel Speech onset: 1176 A onset: 1260 B onset: 2340 C onset: 3060
# file complete YA98_Rel 131.wav : the hammer on the chair above the dog Speech onset: 821 A onset: 900 B onset: 1350 C onset: 2190
# file complete YA98_Rel 136.wav : the mittens and the cake of a leather briefcase Speech onset: 1049 A onset: 1170 B onset: 1680 C onset: 2460
# file complete YA98_Rel 144.wav : the vase is above the skirt and the computer Speech onset: 1350 A onset: 1470 B onset: 2580 C onset: 3240
# file complete YA98_Rel 150.wav : the beat is below the scarf and the canon Speech onset: 1189 A onset: None B onset: None C onset: None
# file complete YA98_Rel 155.wav : the zebra and the helicopter above the sun Speech onset: 954 A onset: 1050 B onset: 1710 C onset: 2910
# file complete YA98_Rel 157.wav : the pillow and the sink are below the tree Speech onset: 1130 A onset: 1260 B onset: 2070 C onset: 3090
# file complete YA98_Rel 160.wav : the will and the acorn are below the clock Speech onset: 1143 A onset: None B onset: None C onset: 1200
# All done!

# %%
import os
# Example usage
def delete_files_with_suffix(folder_path, suffix):
    for filename in os.listdir(folder_path):
        if filename.endswith(suffix):
            file_path = os.path.join(folder_path, filename)
            os.remove(file_path)
            print(f"Deleted file: {file_path}")
folder_path = r"C:\Users\James Belanger\Downloads\drive-download-20230702T014632Z-001"
suffix = "(1).wav"
delete_files_with_suffix(folder_path, suffix)

directories = [name for name in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, name))]
for directory in directories:
    delete_files_with_suffix(os.path.join(folder_path, directory),suffix)
    #print(os.path.join(folder_path, directory))

# %%
import os
# Example usage
def delete_files_with_suffix(folder_path, suffix):
    for filename in os.listdir(folder_path):
        if filename.endswith(suffix):
            file_path = os.path.join(folder_path, filename)
            os.remove(file_path)
            print(f"Deleted file: {file_path}")
folder_path = r"C:\Users\James Belanger\Documents\Relatedness_and_Frequency\Cache"
suffix = "_Results.xlsx"
delete_files_with_suffix(folder_path, suffix)

directories = [name for name in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, name))]
for directory in directories:
    delete_files_with_suffix(os.path.join(folder_path, directory),suffix)
    #print(os.path.join(folder_path, directory))
